# %%
import numpy as np

# %%
s = np.array([1,30,45,23,45])

# %%
print(s.dtype)
# Out:
# int64

# %%
                                            #converting int to float

# %%
s.astype("float64")
# Out:
# array([ 1., 30., 45., 23., 45.])

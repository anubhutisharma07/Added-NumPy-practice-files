# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40,50,70,39,67])

# %%
print(arr[2])
# Out:
# 30

# %%
print(arr[-4])
# Out:
# 50

# %%
print(arr[0:2])
# Out:
# [10 20]

# %%
print(arr[:3])
# Out:
# [10 20 30]

# %%
print(arr[::2])
# Out:
# [10 30 50 39]

# %%
s = arr[2:5]
arr[2]= 23
s.copy()
# Out:
# array([23, 40, 23])

# %%
arr
# Out:
# array([10, 20, 23, 40, 23, 70, 39, 67])

# %%
#Fancy Indexing (Select Multiple Elements)

# %%
s1= np.array([23,4,3,3344,5556,777,23,666,34])

# %%
idx = [3,5,7]
print(s1[idx])
# Out:
# [3344  777  666]

# %%
#Boolean Masking (Filter Data) - codinational values

# %%
arr3 = np.array([10, 20, 30, 40, 50])
arr3[arr3>23]
# Out:
# array([30, 40, 50])
